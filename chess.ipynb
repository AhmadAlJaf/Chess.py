# %%
from IPython.core.display import DisplayHandle
class myclass:
  def __init__(self,xaxis,yaxis,name,logo):
    self.xaxis = xaxis
    self.yaxis = yaxis
    self.name = name
    self.logo = logo
  #def method:
pieces = {
    "wpawn1": myclass(1,7,"wpawn1","♙"),
    "wpawn2": myclass(2,7,"wpawn2"," ♙"),
    "wpawn3": myclass(3,7,"wpawn3","♙"),
    "wpawn4": myclass(4,7,"wpawn4"," ♙"),
    "wpawn5": myclass(5,7,"wpawn5"," ♙"),
    "wpawn6": myclass(6,7,"wpawn6"," ♙"),
    "wpawn7": myclass(7,7,"wpawn7"," ♙"),
    "wpawn8": myclass(8,7,"wpawn8","♙"),
    "wcastleleft": myclass(1,8,"wcastleleft","♖"),
    "wcastleright": myclass(8,8,"wcastleright","♖"),
    "whitehorseleft": myclass(2,8,"whitehorseleft"," ♘"),
    "whitehorseright": myclass(7,8,"whitehorseright"," ♘"),
    "wbishopleft": myclass(3,8,"wbishopleft","♗"),
    "wbishopright": myclass(6,8,"wbishopright"," ♗"),
    "wking": myclass(5,8,"wking"," ♔"),
    "wqueen": myclass(4,8,"wqueen"," ♕"),
    "bpawn1": myclass(1,2,"bpawn1","♟"),
    "bpawn2": myclass(2,2,"bpawn2"," ♟"),
    "bpawn3": myclass(3,2,"bpawn3","♟"),
    "bpawn4": myclass(4,2,"bpawn4"," ♟"),
    "bpawn5": myclass(5,2,"bpawn5"," ♟"),
    "bpawn6": myclass(6,2,"bpawn6"," ♟"),
    "bpawn7": myclass(7,2,"bpawn7"," ♟"),
    "bpawn8": myclass(8,2,"bpawn8","♟"),
    "bcastleleft": myclass(1,1,"bcastleleft","♜"),
    "bcastleright": myclass(8,1,"bcastleright","♜"),
    "bhorseleft": myclass(2,1,"bhorseleft"," ♞"),
    "bhorseright": myclass(7,1,"bhorseright"," ♞"),
    "bbishopleft": myclass(3,1,"bbishopleft","♝"),
    "bbishopright": myclass(6,1,"bbishopright"," ♝"),
    "bking": myclass(5,1,"bking"," ♚"),
    "bqueen": myclass(4,1,"bqueen"," ♛"),
    }


Letters = "error","A","B","C","D","E","F","G","H"
CHOSENPIECE = "none"
def locate(pieces):
  print("Wich piece would you like to enquire?")
  CHOSEN = input()
  if CHOSEN == "wpawn1": CHOSENPIECE = pieces["wpawn1"]
  elif CHOSEN == "wpawn2": CHOSENPIECE = pieces["wpawn2"]
  elif CHOSEN == "wpawn3": CHOSENPIECE = pieces["wpawn3"]
  elif CHOSEN == "wpawn4": CHOSENPIECE = pieces["wpawn4"]
  elif CHOSEN == "wpawn5": CHOSENPIECE = pieces["wpawn5"]
  elif CHOSEN == "wpawn6": CHOSENPIECE = pieces["wpawn6"]
  elif CHOSEN == "wpawn7": CHOSENPIECE = pieces["wpawn7"]
  elif CHOSEN == "wpawn8": CHOSENPIECE = pieces["wpawn8"]
  elif CHOSEN == "wcastleleft": CHOSENPIECE = pieces["wcastleleft"]
  elif CHOSEN == "wcastleright": CHOSENPIECE = pieces["wcastleright"]
  elif CHOSEN == "whitehorseleft": CHOSENPIECE = pieces["whitehorseleft"]
  elif CHOSEN == "whitehorseright": CHOSENPIECE = pieces["whitehorseright"]
  elif CHOSEN == "wbishopleft": CHOSENPIECE = pieces["wbishopleft"]
  elif CHOSEN == "wbishopright": CHOSENPIECE = pieces["wbishopright"]
  elif CHOSEN == "wking": CHOSENPIECE = pieces["wking"]
  elif CHOSEN == "wqueen": CHOSENPIECE = pieces["wqueen"]
  elif CHOSEN == "bpawn1": CHOSENPIECE = pieces["bpawn1"]
  elif CHOSEN == "bpawn2": CHOSENPIECE = pieces["bpawn2"]
  elif CHOSEN == "bpawn3": CHOSENPIECE = pieces["bpawn3"]
  elif CHOSEN == "bpawn4": CHOSENPIECE = pieces["bpawn4"]
  elif CHOSEN == "bpawn5": CHOSENPIECE = pieces["bpawn5"]
  elif CHOSEN == "bpawn6": CHOSENPIECE = pieces["bpawn6"]
  elif CHOSEN == "bpawn7": CHOSENPIECE = pieces["bpawn7"]
  elif CHOSEN == "bpawn8": CHOSENPIECE = pieces["bpawn8"]
  elif CHOSEN == "bcastleleft": CHOSENPIECE = pieces["bcastleleft"]
  elif CHOSEN == "bcastleright": CHOSENPIECE = pieces["bcastleright"]
  elif CHOSEN == "bhorseleft": CHOSENPIECE = pieces["bhorseleft"]
  elif CHOSEN == "bhorseright": CHOSENPIECE = pieces["bhorseright"]
  elif CHOSEN == "bbishopleft": CHOSENPIECE = pieces["bbishopleft"]
  elif CHOSEN == "bbishopright": CHOSENPIECE = pieces["bbishopright"]
  elif CHOSEN == "bking": CHOSENPIECE = pieces["bking"]
  elif CHOSEN == "bqueen": CHOSENPIECE = pieces["bqueen"]
  else: print("ERROR INVALID PIECE")
  POSITION = ("The piece " + CHOSENPIECE.logo + CHOSENPIECE.name + " is at " + Letters[CHOSENPIECE.xaxis] + "," + str(CHOSENPIECE.yaxis))
  print(POSITION)
def advance(pieces):
  print("Wich piece would you like to move?")
  CHOSEN = input()
  if CHOSEN == "wpawn1": CHOSENPIECE = pieces["wpawn1"]
  elif CHOSEN == "wpawn2": CHOSENPIECE = pieces["wpawn2"]
  elif CHOSEN == "wpawn3": CHOSENPIECE = pieces["wpawn3"]
  elif CHOSEN == "wpawn4": CHOSENPIECE = pieces["wpawn4"]
  elif CHOSEN == "wpawn5": CHOSENPIECE = pieces["wpawn5"]
  elif CHOSEN == "wpawn6": CHOSENPIECE = pieces["wpawn6"]
  elif CHOSEN == "wpawn7": CHOSENPIECE = pieces["wpawn7"]
  elif CHOSEN == "wpawn8": CHOSENPIECE = pieces["wpawn8"]
  elif CHOSEN == "wcastleleft": CHOSENPIECE = pieces["wcastleleft"]
  elif CHOSEN == "wcastleright": CHOSENPIECE = pieces["wcastleright"]
  elif CHOSEN == "whitehorseleft": CHOSENPIECE = pieces["whitehorseleft"]
  elif CHOSEN == "whitehorseright": CHOSENPIECE = pieces["whitehorseright"]
  elif CHOSEN == "wbishopleft": CHOSENPIECE = pieces["wbishopleft"]
  elif CHOSEN == "wbishopright": CHOSENPIECE = pieces["wbishopright"]
  elif CHOSEN == "wking": CHOSENPIECE = pieces["wking"]
  elif CHOSEN == "wqueen": CHOSENPIECE = pieces["wqueen"]
  elif CHOSEN == "bpawn1": CHOSENPIECE = pieces["bpawn1"]
  elif CHOSEN == "bpawn2": CHOSENPIECE = pieces["bpawn2"]
  elif CHOSEN == "bpawn3": CHOSENPIECE = pieces["bpawn3"]
  elif CHOSEN == "bpawn4": CHOSENPIECE = pieces["bpawn4"]
  elif CHOSEN == "bpawn5": CHOSENPIECE = pieces["bpawn5"]
  elif CHOSEN == "bpawn6": CHOSENPIECE = pieces["bpawn6"]
  elif CHOSEN == "bpawn7": CHOSENPIECE = pieces["bpawn7"]
  elif CHOSEN == "bpawn8": CHOSENPIECE = pieces["bpawn8"]
  elif CHOSEN == "bcastleleft": CHOSENPIECE = pieces["bcastleleft"]
  elif CHOSEN == "bcastleright": CHOSENPIECE = pieces["bcastleright"]
  elif CHOSEN == "bhorseleft": CHOSENPIECE = pieces["bhorseleft"]
  elif CHOSEN == "bhorseright": CHOSENPIECE = pieces["bhorseright"]
  elif CHOSEN == "bbishopleft": CHOSENPIECE = pieces["bbishopleft"]
  elif CHOSEN == "bbishopright": CHOSENPIECE = pieces["bbishopright"]
  elif CHOSEN == "bking": CHOSENPIECE = pieces["bking"]
  elif CHOSEN == "bqueen": CHOSENPIECE = pieces["bqueen"]
  else: print("ERROR INVALID PIECE")
  print("wich axis would you like to move? X or Y")
  chosenaxis = input()
  if chosenaxis == "X":
    print("Left[L] or Right[R]?")
    direction = input()
    if direction == "L":
      print("How many times?")
      steps = input()
      CHOSENPIECE.xaxis -= int(steps)
    elif direction == "l":
      print("How many times?")
      steps = input()
      CHOSENPIECE.xaxis -= int(steps)
    elif direction == "R":
      print("How many times?")
      steps = input()
      CHOSENPIECE.xaxis += int(steps)
    elif direction == "r":
      print("How many times?")
      steps = input()
      CHOSENPIECE.xaxis += int(steps)
    else: print("INVALID DIRECTION")
  if chosenaxis == "x":
    print("Left[L] or Right[R]?")
    direction = input()
    if direction == "L":
      print("How many times?")
      steps = input()
      CHOSENPIECE.xaxis -= int(steps)
    elif direction == "l":
      print("How many times?")
      steps = input()
      CHOSENPIECE.xaxis -= int(steps)
    elif direction == "R":
      print("How many times?")
      steps = input()
      CHOSENPIECE.xaxis += int(steps)
    elif direction == "r":
      print("How many times?")
      steps = input()
      CHOSENPIECE.xaxis += int(steps)
    else: print("INVALID DIRECTION")
  if chosenaxis == "Y":
    print("Up[W] or Down[S]?")
    direction = input()
    if direction == "W":
      print("How many times?")
      steps = input()
      CHOSENPIECE.yaxis -= int(steps)
    elif direction == "w":
      print("How many times?")
      steps = input()
      CHOSENPIECE.yaxis -= int(steps)
    elif direction == "S":
      print("How many times?")
      steps = input()
      CHOSENPIECE.yaxis += int(steps)
    elif direction == "s":
      print("How many times?")
      steps = input()
      CHOSENPIECE.yaxis += int(steps)
    else: print("INVALID DIRECTION")
  if chosenaxis == "y":
      print("Up[W] or Down[S]?")
      direction = input()
      if direction == "W":
        print("How many times?")
        steps = input()
        CHOSENPIECE.yaxis -= int(steps)
      elif direction == "w":
        print("How many times?")
        steps = input()
        CHOSENPIECE.yaxis -= int(int(steps))
      elif direction == "S":
        print("How many times?")
        steps = input()
        CHOSENPIECE.yaxis += int(steps)
      elif direction == "s":
        print("How many times?")
        steps = input()
        CHOSENPIECE.yaxis += int(steps)
      else: print("INVALID DIRECTION")




  # POSITION = ("The piece " + CHOSENPIECE.logo + CHOSENPIECE.name + " is at " + Letters[CHOSENPIECE.xaxis] + "," + str(CHOSENPIECE.yaxis))
  # print(POSITION)
def show(DISPLAY):
  print(DISPLAY[0])
  print(DISPLAY[1])
  print(DISPLAY[2])
  print(DISPLAY[3])
  print(DISPLAY[4])
  print(DISPLAY[5])
  print(DISPLAY[6])
  print(DISPLAY[7])
  print(DISPLAY[8])
def draw(pieces):
  DISPLAY = [ ["8","⬜", "⬛", "⬜", "⬛", "⬜", "⬛", "⬜", "⬛"], ["7","⬛", "⬜", "⬛", "⬜", "⬛", "⬜", "⬛", "⬜"], ["6","⬜", "⬛", "⬜", "⬛", "⬜", "⬛", "⬜", "⬛"], ["5","⬛", "⬜", "⬛", "⬜", "⬛", "⬜", "⬛", "⬜"], ["4","⬜", "⬛", "⬜", "⬛", "⬜", "⬛", "⬜", "⬛"], ["3","⬛", "⬜", "⬛", "⬜", "⬛", "⬜", "⬛", "⬜"], ["2","⬜", "⬛", "⬜", "⬛", "⬜", "⬛", "⬜", "⬛"], ["1","⬛", "⬜", "⬛", "⬜", "⬛", "⬜", "⬛", "⬜"], ["␀","A "," B"," C "," D "," E "," F ","G ","H"]]
  for pieces in pieces.values():
    ydisp = pieces.yaxis - 1
    xdisp = pieces.xaxis
    DISPLAY[ydisp][xdisp] = pieces.logo
  show(DISPLAY)

FINISH = "no"
while FINISH == "no":
  print("𝗟𝗢𝗖𝗔𝗧𝗘[𝗤] 𝗠𝗢𝗩𝗘[𝗪] 𝗥𝗘𝗙𝗥𝗘𝗦𝗛[𝗘] 𝗘𝗡𝗗[𝗫]")
  choice = input()
  if choice == "Q": locate(pieces)
  elif choice == "q": locate(pieces)
  elif choice == "W": advance(pieces)
  elif choice == "w": advance(pieces)
  elif choice == "E": draw(pieces)
  elif choice == "e": draw(pieces)
  elif choice == "X": FINISH = "𝕄𝔸ℕ𝕌𝔸𝕃𝕃𝕐 𝔼ℕ𝔻𝔼𝔻"
  elif choice == "x": FINISH = "𝕄𝔸ℕ𝕌𝔸𝕃𝕃𝕐 𝔼ℕ𝔻𝔼𝔻"
  draw(pieces)
else: print(FINISH)
# Out:
# 𝗟𝗢𝗖𝗔𝗧𝗘[𝗤] 𝗠𝗢𝗩𝗘[𝗪] 𝗥𝗘𝗙𝗥𝗘𝗦𝗛[𝗘] 𝗘𝗡𝗗[𝗫]
# w
# Wich piece would you like to move?
# wpawn1
# wich axis would you like to move? X or Y
# y
# Up[W] or Down[S]?
# w
# How many times?
# 2
# ['8', '♜', ' ♞', '♝', ' ♛', ' ♚', ' ♝', ' ♞', '♜']
# ['7', '♟', ' ♟', '♟', ' ♟', ' ♟', ' ♟', ' ♟', '♟']
# ['6', '⬜', '⬛', '⬜', '⬛', '⬜', '⬛', '⬜', '⬛']
# ['5', '⬛', '⬜', '⬛', '⬜', '⬛', '⬜', '⬛', '⬜']
# ['4', '♙', '⬛', '⬜', '⬛', '⬜', '⬛', '⬜', '⬛']
# ['3', '⬛', '⬜', '⬛', '⬜', '⬛', '⬜', '⬛', '⬜']
# ['2', '⬜', ' ♙', '♙', ' ♙', ' ♙', ' ♙', ' ♙', '♙']
# ['1', '♖', ' ♘', '♗', ' ♕', ' ♔', ' ♗', ' ♘', '♖']
# ['␀', 'A ', ' B', ' C ', ' D ', ' E ', ' F ', 'G ', 'H']
# 𝗟𝗢𝗖𝗔𝗧𝗘[𝗤] 𝗠𝗢𝗩𝗘[𝗪] 𝗥𝗘𝗙𝗥𝗘𝗦𝗛[𝗘] 𝗘𝗡𝗗[𝗫]
# q
# Wich piece would you like to enquire?
# wpawn1
# The piece ♙wpawn1 is at A,5
# ['8', '♜', ' ♞', '♝', ' ♛', ' ♚', ' ♝', ' ♞', '♜']
# ['7', '♟', ' ♟', '♟', ' ♟', ' ♟', ' ♟', ' ♟', '♟']
# ['6', '⬜', '⬛', '⬜', '⬛', '⬜', '⬛', '⬜', '⬛']
# ['5', '⬛', '⬜', '⬛', '⬜', '⬛', '⬜', '⬛', '⬜']
# ...
